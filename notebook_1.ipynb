# %%
print("Hello world")

# %% [markdown]
# Hello, so this is prob where I will write my research project. I have already made this enviorment into and IDE, so there should be no need to install PyCharm or other IDEs unless working in a group perphas...
